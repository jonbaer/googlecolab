# %% [markdown]
# <a href="https://colab.research.google.com/github/jonbaer/googlecolab/blob/master/core_five.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌐 core-five: Multi-Modal Geospatial Dataset for Foundational Research
# Welcome to the official Colab notebook for accessing and exploring **core-five**, a harmonized dataset across multiple satellite modalities (HighRes, Sentinel-1, Sentinel-2, Landsat, MODIS).
#
# > **🧠 What’s inside?**
# > - Unified geospatial datacube
# > - Temporal alignment across sensors
# > - Ready for Foundation Models, SSL, and benchmarking
#
# ---

# %% [markdown]
# ## 📦 Accessing core-five Data using HF
# We'll use `xarray`, `fsspec`, and `rioxarray` to load data directly from the Hugging Face Hub.

# %%
import numpy as np
import pandas as pd
import geopandas as gpd

import os
import fsspec
import xarray as xr
import huggingface_hub as hf

# %% [markdown]
# > 💡 **Tip:** Use Dask with `xr.open_datatree(..., chunks={})` for large-scale scalable workflows.

# %% [markdown]
# ### 🧬 Metadata Loader: Zero-copy, Zero-hassle, Metadata of Each cube
#
# Streaming GeoParquet directly from Hugging Face with `fsspec` + `GeoPandas` — no local downloads, no clutter:

# %%
metadata_url = "https://huggingface.co/datasets/gajeshladhar/core-five/resolve/main/metadata.parquet"
df_metadata = gpd.read_parquet(fsspec.open(metadata_url).open())
df_metadata.head()
# Out:
#                               path  \
# 0  src/datatree/0097b3/00964b34.nc
# 1  src/datatree/0097b3/00964b4c.nc
# 2  src/datatree/00989b/00988334.nc
# 3  src/datatree/00989b/0098834c.nc
# 4  src/datatree/0098f5/009858ac.nc
#
#                                             geometry
# 0  POLYGON ((-41.91965 -22.51009, -41.90972 -22.5...
# 1  POLYGON ((-41.91965 -22.51976, -41.90972 -22.5...
# 2  POLYGON ((-43.32947 -21.75015, -43.31981 -21.7...
# 3  POLYGON ((-43.32947 -21.75967, -43.31981 -21.7...
# 4  POLYGON ((-43.17472 -22.13415, -43.16503 -22.1...

# %% [markdown]
# ### 🎲 On-the-Fly Access to a Random Scene
#
# Select and stream a sample `.nc` file from the Hugging Face dataset — directly indexed via metadata:

# %%
path = os.path.join("https://huggingface.co/datasets/gajeshladhar/core-five/resolve/main/",df_metadata.sample(n=1).path.iloc[0])
path
# Out:
# 'https://huggingface.co/datasets/gajeshladhar/core-five/resolve/main/src/datatree/602187/60218764.nc'

# %%
# %%time
tree = xr.open_datatree(path)
tree
# Out:
# CPU times: user 1.52 s, sys: 220 ms, total: 1.74 s
# Wall time: 10.2 s
# <xarray.DataTree>
# Group: /
# │   Attributes:
# │       s2id:     60218764
# │       polygon:  POLYGON ((140.56532941674737 36.526128716864015, 140.5653294167...
# │       crs:      EPSG:32654
# ├── Group: /s2
# │       Dimensions:      (time: 23, y: 150, x: 96)
# │       Coordinates:
# │         * y            (y) float64 1kB 4.041e+06 4.041e+06 ... 4.043e+06 4.043e+06
# │         * x            (x) float64 768B 4.611e+05 4.611e+05 ... 4.62e+05 4.62e+05
# │           spatial_ref  int32 4B ...
# │         * time         (time) datetime64[ns] 184B 2024-12-27T01:30:51.024000 ... 20...
# │       Data variables: (12/16)
# │           AOT          (time, y, x) float32 1MB ...
# │           B01          (time, y, x) float32 1MB ...
# │           B02          (time, y, x) float32 1MB ...
# │           B03          (time, y, x) float32 1MB ...
# │           B04          (time, y, x) float32 1MB ...
# │           B05          (time, y, x) float32 1MB ...
# │           ...           ...
# │           B11          (time, y, x) float32 1MB ...
# │           B12          (time, y, x) float32 1MB ...
# │           B8A          (time, y, x) float32 1MB ...
# │           SCL          (time, y, x) float32 1MB ...
# │           WVP          (time, y, x) float32 1MB ...
# │           visual       (time, y, x) float32 1MB ...
# ├── Group: /s1
# │       Dimensions:      (time: 4, y: 150, x: 96)
# │       Coordinates:
# │         * y            (y) float64 1kB 4.041e+06 4.041e+06 ... 4.043e+06 4.043e+06
# │         * x            (x) float64 768B 4.611e+05 4.611e+05 ... 4.62e+05 4.62e+05
# │           spatial_ref  int32 4B ...
# │         * time         (time) datetime64[ns] 32B 2025-01-07T20:43:38.498295 ... 202...
# │       Data variables:
# │           vh           (time, y, x) float32 230kB ...
# │           vv           (time, y, x) float32 230kB ...
# ├── Group: /modis
# │       Dimensions:       (time: 8, y: 7, x: 5)
# │       Coordinates:
# │         * y             (y) float64 56B 4.041e+06 4.042e+06 ... 4.043e+06 4.043e+06
# │         * x             (x) float64 40B 4.611e+05 4.614e+05 ... 4.619e+05 4.621e+05
# │           spatial_ref   int32 4B ...
# │         * time          (time) datetime64[ns] 64B 2024-12-26 2025-01-01 ... 2025-02-18
# │       Data variables:
# │           sur_refl_b01  (time, y, x) float32 1kB ...
# │           sur_refl_b02  (time, y, x) float32 1kB ...
# │           sur_refl_b03  (time, y, x) float32 1kB ...
# │           sur_refl_b04  (time, y, x) float32 1kB ...
# │           sur_refl_b05  (time, y, x) float32 1kB ...
# │           sur_refl_b06  (time, y, x) float32 1kB ...
# │           sur_refl_b07  (time, y, x) float32 1kB ...
# ├── Group: /landsat
# │       Dimensions:      (time: 8, y: 50, x: 32)
# │       Coordinates:
# │         * y            (y) float64 400B 4.041e+06 4.041e+06 ... 4.043e+06 4.043e+06
# │         * x            (x) float64 256B 4.611e+05 4.611e+05 ... 4.62e+05 4.62e+05
# │           spatial_ref  int32 4B ...
# │         * time         (time) datetime64[ns] 64B 2024-12-28T01:15:59.923950 ... 202...
# │       Data variables: (12/19)
# │           qa           (time, y, x) float32 51kB ...
# │           red          (time, y, x) float32 51kB ...
# │           blue         (time, y, x) float32 51kB ...
# │           drad         (time, y, x) float32 51kB ...
# │           emis         (time, y, x) float32 51kB ...
# │           emsd         (time, y, x) float32 51kB ...
# │           ...           ...
# │           swir16       (time, y, x) float32 51kB ...
# │           swir22       (time, y, x) float32 51kB ...
# │           coastal      (time, y, x) float32 51kB ...
# │           qa_pixel     (time, y, x) float32 51kB ...
# │           qa_radsat    (time, y, x) float32 51kB ...
# │           qa_aerosol   (time, y, x) float32 51kB ...
# └── Group: /hr
#         Dimensions:      (band: 3, y: 6231, x: 3968)
#         Coordinates:
#           * x            (x) float64 32kB 4.611e+05 4.611e+05 ... 4.62e+05 4.62e+05
#           * y            (y) float64 50kB 4.041e+06 4.041e+06 ... 4.043e+06 4.043e+06
#           * band         (band) int64 24B 1 2 3
#         Data variables:
#             data         (band, y, x) float64 593MB ...
#             spatial_ref  int64 8B ...

# %% [markdown]
# ### 🌳 Navigating the DataTree: Modalities Unfolded
#
# Each `.nc` file is exposed as a structured `xarray`-based `DataTree`. You can directly access nested groups like a filesystem.
#
# Below is a visual representation of how different modalities are structured:
#
# ```
# 📂 root
# ├── 🛰️ s2
# │   ├── B02  ← Blue
# │   ├── B03  ← Green
# │   ├── B04  ← Red
# │   ├── B05  ← Red Edge 1
# │   ├── B06  ← Red Edge 2
# │   ├── ...  ← More bands (B07 to B12)
# ├── 📡 s1
# │   ├── vv   ← Vertical transmit/receive
# │   ├── vh   ← Vertical transmit, horizontal receive
# │   └── ...  ← (Polarimetric or derived bands)
# ├── 🛰️ landsat
# │   ├── red
# │   ├── green
# │   ├── blue
# │   ├── nir
# │   ├── swir1
# │   ├── swir2
# │   └── ...  ← (Thermal or quality bands)
# ├── 🌍 modis
# │   ├── sur_refl_b01  ← Red
# │   ├── sur_refl_b03  ← Blue
# │   ├── sur_refl_b04  ← Green
# │   ├── sur_refl_b05
# │   ├── ...
# └── 🔍 hr
#     └── data  ← High-res 25cm image
# ```

# %%
ds_s2 = xr.concat([tree['s2/B04'], tree['s2/B03'], tree['s2/B02']],dim=pd.Index(['B04','B03','B02'],name='band'))
ds_s1 = xr.concat([tree['s1/vv'], tree['s1/vh']],dim=pd.Index(['vv','vh'],name='band'))

ds_landsat = xr.concat([tree['landsat/red'], tree['landsat/green'], tree['landsat/blue']],dim=pd.Index(['red','green','blue'],name='band'))
ds_modis = xr.concat([tree['modis/sur_refl_b01'], tree['modis/sur_refl_b04'], tree['modis/sur_refl_b03']],dim=pd.Index(['red','green','blue'],name='band'))

ds_hr = tree['hr/data']

# %% [markdown]
# ## 🛰️ Quick Visualization
# We'll preview one modality using `hvplot` or `matplotlib` for a quick visual sanity check.
