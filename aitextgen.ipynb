# %% [markdown]
# <a href="https://colab.research.google.com/github/jonbaer/googlecolab/blob/master/aitextgen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install aitextgen
from aitextgen import aitextgen
# Out:
# ...
#      |████████████████████████████████| 573kB 2.7MB/s
# ...
#      |████████████████████████████████| 645kB 12.9MB/s
# ...
#      |████████████████████████████████| 81kB 7.9MB/s
# ...
#      |████████████████████████████████| 256kB 16.3MB/s
# ...
#      |████████████████████████████████| 3.8MB 16.6MB/s
# ...
#      |████████████████████████████████| 890kB 42.8MB/s
# ...
#      |████████████████████████████████| 1.1MB 17.8MB/s
# ...
#      |████████████████████████████████| 829kB 39.4MB/s
# ...
#   Created wheel for aitextgen: filename=aitextgen-0.1.1-cp36-none-any.whl size=571367 sha256=7ceefae1f2c23d1996e40aaad5935a6f1b52358628bbaec96bfd293a6946b7de
#   Stored in directory: /root/.cache/pip/wheels/58/15/b6/9574fb6b5bbdd9ae9b94082d601e4ca0d4b85738e9ae99a0ac
# ...
#   Created wheel for fire: filename=fire-0.3.1-py2.py3-none-any.whl size=111005 sha256=31f9d11bb405f49b96d3542bc2a9440ff484f1a8cdf915c2c06ab7311ce89699
#   Stored in directory: /root/.cache/pip/wheels/c1/61/df/768b03527bf006b546dce284eb4249b185669e65afc5fbb2ac
# ...

# %%
ai = aitextgen()
ai.generate()
ai.generate(n=3, max_length=100)
ai.generate(n=3, max_length=100, prompt="In the next few years China will")
# Out:
# INFO:aitextgen:Downloading gpt2 model to /aitextgen.
# ...
# INFO:aitextgen:Using the default GPT-2 Tokenizer.
# I've been a fan of the comics for a long time. When I first started collecting, my childhood passion was comics. Now I'm a full-time hobbyist, but those comics are still my main source of income. I just hope to keep collecting them as long as I can.
# Praise be to Allaah.
#
# O Allah, if you are in doubt about your faith, then pray for the believers.
#
# It is not permitted to insult or make a joke in the presence of Allaah.
#
# O Messenger of Allaah (peace and blessings of Allaah be upon him) and peace be upon the companions of Allaah, and be mindful of the prayer of the believers.
#
# It is not permissible to insult one's religion, or the believers, and to make a
# ...

# %%
ai = aitextgen(model="minimaxir/hacker-news")
ai.generate()
ai.generate(5)
ai.generate(5, prompt="Google says")
# Out:
# INFO:aitextgen:Loading minimaxir/hacker-news model from /aitextgen.
# ...
# INFO:aitextgen:Using the tokenizer for minimaxir/hacker-news.
# ...
# Job Posts Growing Up, Then Soonyer Is World’s Audience May Not Exist on What We Can’t
# The Mysterious Case of the Duke University?
# ...
# Show HN: A new game engine – how I found the effect in the wild
# ...
# Africa's Public Health Futures
# ...
# Myths About Introverts
# ...
# Humble Book Bundle: Computer Networks, Web Apps, and Web 2.0 (2011)
# Google says the company is down
# ...
# Google says it's uncensorable by category theory
# ...
# Google says it will buy Zoom
# ...
# Google says sorry for sailing or overseas
# ...
# Google says it will adopt Internet Explorer 9

# %%
ai = aitextgen(model="minimaxir/reddit")
ai.generate()
ai.generate(5)
ai.generate(5, prompt="In the next few years China will")
# Out:
# INFO:aitextgen:Loading minimaxir/reddit model from /aitextgen.
# ...
# INFO:aitextgen:Using the tokenizer for minimaxir/reddit.
# ...
# psvr The Lowest PSVR has ever released.
# fortnitefashion The new gearbox is finally finished!
# ...
# nursing Ahhhhhh...
# ...
# chonkers Oh lawd he definitely didn't think he was a chonker
# ...
# assassinscreed Assassin's Creed Odyssey 2 is now the only way to beat Greed.
# ...
# nursing MRW when my patient's friend asks me to not buy it, they make the whole day
# In the next few years China will be a published in a bunch of houses.
# ...
# In the next few years China will be the greatest of all time.
# ...
# In the next few years China will be a new farming team.
# ...
# In the next few years China will not be able to use Stealth Regional
# ...
# In the next few years China will be required to make it a new year!
